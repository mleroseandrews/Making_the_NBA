# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import StandardScaler,OneHotEncoder,MinMaxScaler, LabelEncoder

# %%
Grouped_Player_Avgs_data = os.path.join('../CleanData/Players_Avg_Stats_09_21_clean.csv')
Grouped_Player_Avgs_df = pd.read_csv(Grouped_Player_Avgs_data)
Grouped_Player_Avgs_df
# Out:
#          pid    GP    Min_per   Ortg        usg        eFG     TS_per  \
# 0          2  26.0  29.500000   97.3  16.600000  42.500000  44.430000
# 1          3  33.0  63.133333  107.4  17.233333  51.166667  53.403333
# 2          5  27.0  72.000000   96.2  21.800000  45.700000  47.980000
# 3          8  30.0  44.500000   97.7  16.000000  53.600000  53.690000
# 4          9  33.0  56.200000   96.5  22.000000  52.800000  54.310000
# ...      ...   ...        ...    ...        ...        ...        ...
# 22364  74196   8.0   3.700000   92.7  13.400000  40.000000  45.660000
# 22365  74203  16.0  12.900000  129.5  13.200000  67.900000  65.840000
# 22366  74213  10.0   5.900000   47.2  28.600000  11.900000  17.110000
# 22367  74217   9.0  17.100000   86.9  21.800000  39.100000  40.090000
# 22368  74218  13.0  11.000000   99.1  15.100000  60.000000  55.370000
#
#        ORB_per  DRB_per  AST_per  ...        pts  Drafted  Round_Drafted  \
# ...

# %%
Conferences_to_keep = ['ACC','SEC','B12','P12','B10','BE','MWC','P10','WCC','Amer','A10','CUSA','OVC','Horz','CAA',
                       'WAC','SB','Pat','BSky','Sum','SC','MVC','MAC','BW','MEAC','Ivy']

# %%
Grouped_Player_Avgs_df= Grouped_Player_Avgs_df[Grouped_Player_Avgs_df['Last_Yr_in_College_conf'].isin(Conferences_to_keep)]
Grouped_Player_Avgs_df
# Out:
#          pid    GP    Min_per   Ortg        usg        eFG     TS_per  \
# 0          2  26.0  29.500000   97.3  16.600000  42.500000  44.430000
# 1          3  33.0  63.133333  107.4  17.233333  51.166667  53.403333
# 2          5  27.0  72.000000   96.2  21.800000  45.700000  47.980000
# 3          8  30.0  44.500000   97.7  16.000000  53.600000  53.690000
# 4          9  33.0  56.200000   96.5  22.000000  52.800000  54.310000
# ...      ...   ...        ...    ...        ...        ...        ...
# 22364  74196   8.0   3.700000   92.7  13.400000  40.000000  45.660000
# 22365  74203  16.0  12.900000  129.5  13.200000  67.900000  65.840000
# 22366  74213  10.0   5.900000   47.2  28.600000  11.900000  17.110000
# 22367  74217   9.0  17.100000   86.9  21.800000  39.100000  40.090000
# 22368  74218  13.0  11.000000   99.1  15.100000  60.000000  55.370000
#
#        ORB_per  DRB_per  AST_per  ...        pts  Drafted  Round_Drafted  \
# ...

# %%
Grouped_Player_Avgs_df['Last_Yr_in_College_conf'].unique()
# Out:
# array(['SB', 'WAC', 'BE', 'WCC', 'BW', 'Horz', 'A10', 'ACC', 'SEC', 'Pat',
#        'CAA', 'MVC', 'MAC', 'B12', 'CUSA', 'MEAC', 'P10', 'B10', 'SC',
#        'Ivy', 'Sum', 'MWC', 'BSky', 'OVC', 'P12', 'Amer'], dtype=object)

# %%
enc = LabelEncoder()

enc_column = enc.fit_transform(Grouped_Player_Avgs_df['Last_Yr_in_College_team'])
enc_column2 = enc.fit_transform(Grouped_Player_Avgs_df['Last_Yr_in_College_conf'])

Grouped_Player_Avgs_df['Last_Yr_in_College_team'] = enc_column
Grouped_Player_Avgs_df['Last_Yr_in_College_conf'] = enc_column2

Grouped_Player_Avgs_df
# Out:
# C:\Users\tyler\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\tyler\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#          pid    GP    Min_per   Ortg        usg        eFG     TS_per  \
# 0          2  26.0  29.500000   97.3  16.600000  42.500000  44.430000
# 1          3  33.0  63.133333  107.4  17.233333  51.166667  53.403333
# ...

# %%
drop_list = ['rimmade','rimmade+rimmiss',
            'midmade','midmade+midmiss','rimmade/(rimmade+rimmiss)',
            'midmade/(midmade+midmiss)','dunksmade','dunksmiss+dunksmade',
            'dunksmade/(dunksmade+dunksmiss)']

# %%
Grouped_Player_Avgs_Clean = Grouped_Player_Avgs_df.drop(columns=drop_list)
Grouped_Player_Avgs_Clean
# Out:
#          pid    GP    Min_per   Ortg        usg        eFG     TS_per  \
# 0          2  26.0  29.500000   97.3  16.600000  42.500000  44.430000
# 1          3  33.0  63.133333  107.4  17.233333  51.166667  53.403333
# 2          5  27.0  72.000000   96.2  21.800000  45.700000  47.980000
# 3          8  30.0  44.500000   97.7  16.000000  53.600000  53.690000
# 4          9  33.0  56.200000   96.5  22.000000  52.800000  54.310000
# ...      ...   ...        ...    ...        ...        ...        ...
# 22364  74196   8.0   3.700000   92.7  13.400000  40.000000  45.660000
# 22365  74203  16.0  12.900000  129.5  13.200000  67.900000  65.840000
# 22366  74213  10.0   5.900000   47.2  28.600000  11.900000  17.110000
# 22367  74217   9.0  17.100000   86.9  21.800000  39.100000  40.090000
# 22368  74218  13.0  11.000000   99.1  15.100000  60.000000  55.370000
#
#        ORB_per  DRB_per  AST_per  ...        pts  Drafted  Round_Drafted  \
# ...

# %%
Grouped_Player_Avgs_Clean= Grouped_Player_Avgs_Clean[Grouped_Player_Avgs_Clean['mp'] >= 7.48]
Grouped_Player_Avgs_Clean
# Out:
#          pid    GP    Min_per   Ortg        usg        eFG     TS_per  \
# 0          2  26.0  29.500000   97.3  16.600000  42.500000  44.430000
# 1          3  33.0  63.133333  107.4  17.233333  51.166667  53.403333
# 2          5  27.0  72.000000   96.2  21.800000  45.700000  47.980000
# 3          8  30.0  44.500000   97.7  16.000000  53.600000  53.690000
# 4          9  33.0  56.200000   96.5  22.000000  52.800000  54.310000
# ...      ...   ...        ...    ...        ...        ...        ...
# 22359  74187  19.0  57.800000  109.5  17.500000  59.100000  61.380000
# 22361  74190  18.0  47.500000   67.4  20.700000  37.200000  38.000000
# 22365  74203  16.0  12.900000  129.5  13.200000  67.900000  65.840000
# 22367  74217   9.0  17.100000   86.9  21.800000  39.100000  40.090000
# 22368  74218  13.0  11.000000   99.1  15.100000  60.000000  55.370000
#
#        ORB_per  DRB_per  AST_per  ...        pts  Drafted  Round_Drafted  \
# ...

# %%
Drafted_df = Grouped_Player_Avgs_Clean[Grouped_Player_Avgs_Clean['Drafted'] == 1]
Drafted_df
# Out:
#          pid         GP    Min_per        Ortg        usg        eFG  \
# 32        57  32.000000  90.033333  112.300000  29.200000  50.200000
# 49        91  35.500000  61.100000  111.900000  22.050000  60.000000
# 106      193  33.000000  51.100000   89.750000  19.000000  46.550000
# 108      197  38.000000  85.733333  113.833333  24.500000  49.900000
# 109      198  36.333333  73.000000  111.600000  25.033333  49.633333
# ...      ...        ...        ...         ...        ...        ...
# 22072  73518  29.000000  47.900000  101.900000  27.500000  51.900000
# 22074  73524  25.000000  51.100000  108.000000  21.300000  54.000000
# 22143  73630  26.000000  48.900000   91.700000  25.800000  49.700000
# 22178  73686  27.000000  62.500000   95.200000  27.300000  47.400000
# 22208  73723  25.000000  75.900000   96.400000  21.400000  40.700000
#
#           TS_per    ORB_per    DRB_per    AST_per  ...        pts  Drafted  \
# ...

# %%
Undrafted_df = Grouped_Player_Avgs_Clean[Grouped_Player_Avgs_Clean['Drafted'] == 0]
Undrafted_df
# Out:
#          pid    GP    Min_per   Ortg        usg        eFG     TS_per  \
# 0          2  26.0  29.500000   97.3  16.600000  42.500000  44.430000
# 1          3  33.0  63.133333  107.4  17.233333  51.166667  53.403333
# 2          5  27.0  72.000000   96.2  21.800000  45.700000  47.980000
# 3          8  30.0  44.500000   97.7  16.000000  53.600000  53.690000
# 4          9  33.0  56.200000   96.5  22.000000  52.800000  54.310000
# ...      ...   ...        ...    ...        ...        ...        ...
# 22359  74187  19.0  57.800000  109.5  17.500000  59.100000  61.380000
# 22361  74190  18.0  47.500000   67.4  20.700000  37.200000  38.000000
# 22365  74203  16.0  12.900000  129.5  13.200000  67.900000  65.840000
# 22367  74217   9.0  17.100000   86.9  21.800000  39.100000  40.090000
# 22368  74218  13.0  11.000000   99.1  15.100000  60.000000  55.370000
#
#        ORB_per  DRB_per  AST_per  ...        pts  Drafted  Round_Drafted  \
# ...

# %%
Undrafted_df = Undrafted_df.sample(n=6200)
Undrafted_df
# Out:
#          pid    GP    Min_per        Ortg        usg        eFG     TS_per  \
# 17293  50939  30.0  46.366667   96.133333  17.833333  54.933333  55.413333
# 20536  71144  23.0  24.400000   90.000000  14.200000  53.600000  53.460000
# 9622   28057  31.0  48.633333   98.566667  17.066667  45.600000  50.123333
# 11728  34582  28.0  61.125000  107.275000  26.200000  53.775000  58.217500
# 4204   11590  28.5  28.600000  109.650000  16.500000  55.550000  55.030000
# ...      ...   ...        ...         ...        ...        ...        ...
# 9180   26718  31.5  48.800000   96.000000  19.050000  46.300000  52.130000
# 21453  72511  15.0  15.000000   50.100000  16.100000  28.300000  27.140000
# 1992    3631  31.0  38.700000   90.100000  12.800000  51.900000  48.850000
# 6084   17107  29.0  52.433333   96.233333  15.433333  43.233333  48.563333
# 13841  40844  25.0  33.200000  108.750000  19.000000  57.350000  56.930000
#
#          ORB_per    DRB_per    AST_per  ...        pts  Drafted  \
# ...

# %%
Undrafted_df.Last_Yr_in_College_Date_Yr.unique()
# Out:
# array([2021, 2016, 2018, 2011, 2009, 2017, 2010, 2014, 2013, 2015, 2019,
#        2020, 2012], dtype=int64)

# %%
Equal_df = pd.concat([Drafted_df,Undrafted_df])
Equal_df
# Out:
#          pid         GP    Min_per        Ortg        usg        eFG  \
# 32        57  32.000000  90.033333  112.300000  29.200000  50.200000
# 49        91  35.500000  61.100000  111.900000  22.050000  60.000000
# 106      193  33.000000  51.100000   89.750000  19.000000  46.550000
# 108      197  38.000000  85.733333  113.833333  24.500000  49.900000
# 109      198  36.333333  73.000000  111.600000  25.033333  49.633333
# ...      ...        ...        ...         ...        ...        ...
# 9180   26718  31.500000  48.800000   96.000000  19.050000  46.300000
# 21453  72511  15.000000  15.000000   50.100000  16.100000  28.300000
# 1992    3631  31.000000  38.700000   90.100000  12.800000  51.900000
# 6084   17107  29.000000  52.433333   96.233333  15.433333  43.233333
# 13841  40844  25.000000  33.200000  108.750000  19.000000  57.350000
#
#           TS_per    ORB_per    DRB_per    AST_per  ...        pts  Drafted  \
# ...

# %%
Categorical_Columns = Equal_df.dtypes[Equal_df.dtypes == "object"].index.tolist()
Categorical_Columns
# Out:
# ['player_name', 'Last_Yr_in_College_School_Yr', 'Last_Yr_in_College_Position']

# %%
Equal_df.groupby('Number_of_Yrs_Played',as_index=False)['Number_of_Yrs_Played'].count()
# Out:
#    Number_of_Yrs_Played
# 0                  1587
# 1                  1928
# 2                  1282
# 3                  1999
# 4                    31

# %%
Variables_df = Equal_df
Variables_df
# Out:
#          pid         GP    Min_per        Ortg        usg        eFG  \
# 32        57  32.000000  90.033333  112.300000  29.200000  50.200000
# 49        91  35.500000  61.100000  111.900000  22.050000  60.000000
# 106      193  33.000000  51.100000   89.750000  19.000000  46.550000
# 108      197  38.000000  85.733333  113.833333  24.500000  49.900000
# 109      198  36.333333  73.000000  111.600000  25.033333  49.633333
# ...      ...        ...        ...         ...        ...        ...
# 9180   26718  31.500000  48.800000   96.000000  19.050000  46.300000
# 21453  72511  15.000000  15.000000   50.100000  16.100000  28.300000
# 1992    3631  31.000000  38.700000   90.100000  12.800000  51.900000
# 6084   17107  29.000000  52.433333   96.233333  15.433333  43.233333
# 13841  40844  25.000000  33.200000  108.750000  19.000000  57.350000
#
#           TS_per    ORB_per    DRB_per    AST_per  ...        pts  Drafted  \
# ...

# %%
#Drop Columns that aren't variables to predicting drafted/undrafted
Variables_df = Variables_df.drop(columns=['pid','player_name','pick','Drafted','Round_Drafted'])
Variables_df
# Out:
#               GP    Min_per        Ortg        usg        eFG     TS_per  \
# 32     32.000000  90.033333  112.300000  29.200000  50.200000  56.323333
# 49     35.500000  61.100000  111.900000  22.050000  60.000000  59.310000
# 106    33.000000  51.100000   89.750000  19.000000  46.550000  50.070000
# 108    38.000000  85.733333  113.833333  24.500000  49.900000  54.343333
# 109    36.333333  73.000000  111.600000  25.033333  49.633333  54.560000
# ...          ...        ...         ...        ...        ...        ...
# 9180   31.500000  48.800000   96.000000  19.050000  46.300000  52.130000
# 21453  15.000000  15.000000   50.100000  16.100000  28.300000  27.140000
# 1992   31.000000  38.700000   90.100000  12.800000  51.900000  48.850000
# 6084   29.000000  52.433333   96.233333  15.433333  43.233333  48.563333
# 13841  25.000000  33.200000  108.750000  19.000000  57.350000  56.930000
#
#          ORB_per    DRB_per    AST_per     TO_per  ...       ast       stl  \
# ...

# %%
Categorical_Columns = Variables_df.dtypes[Variables_df.dtypes == "object"].index.tolist()
Categorical_Columns
# Out:
# ['Last_Yr_in_College_School_Yr', 'Last_Yr_in_College_Position']

# %%
#Encode School_Yr
School_Yr_dict = {
    'Fr':1,
    'So':2,
    'Jr':3,
    'Sr':4
}

# %%
Variables_df["Last_Yr_in_College_School_Yr_Num"] = Variables_df["Last_Yr_in_College_School_Yr"].apply(lambda x: School_Yr_dict[x])
Variables_df
# Out:
#               GP    Min_per        Ortg        usg        eFG     TS_per  \
# 32     32.000000  90.033333  112.300000  29.200000  50.200000  56.323333
# 49     35.500000  61.100000  111.900000  22.050000  60.000000  59.310000
# 106    33.000000  51.100000   89.750000  19.000000  46.550000  50.070000
# 108    38.000000  85.733333  113.833333  24.500000  49.900000  54.343333
# 109    36.333333  73.000000  111.600000  25.033333  49.633333  54.560000
# ...          ...        ...         ...        ...        ...        ...
# 9180   31.500000  48.800000   96.000000  19.050000  46.300000  52.130000
# 21453  15.000000  15.000000   50.100000  16.100000  28.300000  27.140000
# 1992   31.000000  38.700000   90.100000  12.800000  51.900000  48.850000
# 6084   29.000000  52.433333   96.233333  15.433333  43.233333  48.563333
# 13841  25.000000  33.200000  108.750000  19.000000  57.350000  56.930000
#
#          ORB_per    DRB_per    AST_per     TO_per  ...       stl       blk  \
# ...

# %%
Variables_df = Variables_df.drop(columns = ['Last_Yr_in_College_School_Yr'], axis=1)
Variables_df
# Out:
#               GP    Min_per        Ortg        usg        eFG     TS_per  \
# 32     32.000000  90.033333  112.300000  29.200000  50.200000  56.323333
# 49     35.500000  61.100000  111.900000  22.050000  60.000000  59.310000
# 106    33.000000  51.100000   89.750000  19.000000  46.550000  50.070000
# 108    38.000000  85.733333  113.833333  24.500000  49.900000  54.343333
# 109    36.333333  73.000000  111.600000  25.033333  49.633333  54.560000
# ...          ...        ...         ...        ...        ...        ...
# 9180   31.500000  48.800000   96.000000  19.050000  46.300000  52.130000
# 21453  15.000000  15.000000   50.100000  16.100000  28.300000  27.140000
# 1992   31.000000  38.700000   90.100000  12.800000  51.900000  48.850000
# 6084   29.000000  52.433333   96.233333  15.433333  43.233333  48.563333
# 13841  25.000000  33.200000  108.750000  19.000000  57.350000  56.930000
#
#          ORB_per    DRB_per    AST_per     TO_per  ...       ast       stl  \
# ...

# %%
Variables_df_cat_encoded = pd.get_dummies(Variables_df, columns=['Last_Yr_in_College_Position'])
Variables_df_cat_encoded
# Out:
#               GP    Min_per        Ortg        usg        eFG     TS_per  \
# 32     32.000000  90.033333  112.300000  29.200000  50.200000  56.323333
# 49     35.500000  61.100000  111.900000  22.050000  60.000000  59.310000
# 106    33.000000  51.100000   89.750000  19.000000  46.550000  50.070000
# 108    38.000000  85.733333  113.833333  24.500000  49.900000  54.343333
# 109    36.333333  73.000000  111.600000  25.033333  49.633333  54.560000
# ...          ...        ...         ...        ...        ...        ...
# 9180   31.500000  48.800000   96.000000  19.050000  46.300000  52.130000
# 21453  15.000000  15.000000   50.100000  16.100000  28.300000  27.140000
# 1992   31.000000  38.700000   90.100000  12.800000  51.900000  48.850000
# 6084   29.000000  52.433333   96.233333  15.433333  43.233333  48.563333
# 13841  25.000000  33.200000  108.750000  19.000000  57.350000  56.930000
#
#          ORB_per    DRB_per    AST_per     TO_per  ...  \
# ...

# %%
Variables_df_cat_encoded = Variables_df_cat_encoded.drop(columns=['Last_Yr_in_College_Position_Unknown'])
Variables_df_cat_encoded
# Out:
#               GP    Min_per        Ortg        usg        eFG     TS_per  \
# 32     32.000000  90.033333  112.300000  29.200000  50.200000  56.323333
# 49     35.500000  61.100000  111.900000  22.050000  60.000000  59.310000
# 106    33.000000  51.100000   89.750000  19.000000  46.550000  50.070000
# 108    38.000000  85.733333  113.833333  24.500000  49.900000  54.343333
# 109    36.333333  73.000000  111.600000  25.033333  49.633333  54.560000
# ...          ...        ...         ...        ...        ...        ...
# 9180   31.500000  48.800000   96.000000  19.050000  46.300000  52.130000
# 21453  15.000000  15.000000   50.100000  16.100000  28.300000  27.140000
# 1992   31.000000  38.700000   90.100000  12.800000  51.900000  48.850000
# 6084   29.000000  52.433333   96.233333  15.433333  43.233333  48.563333
# 13841  25.000000  33.200000  108.750000  19.000000  57.350000  56.930000
#
#          ORB_per    DRB_per    AST_per     TO_per  ...  \
# ...

# %%
Target = Equal_df['Drafted'].values
Target
# Out:
# array([1., 1., 1., ..., 0., 0., 0.])

# %%
X=Variables_df_cat_encoded
y=Target
print(len(X))
print(len(y))
# Out:
# 6827
# 6827

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Splitting into Train and Test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (5120, 57)
# (1707, 57)
# (5120,)
# (1707,)

# %%
# Creating StandardScaler instance
scaler = StandardScaler()

# %%
# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# %%
# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

print(X_train_scaled.shape)
print(X_test_scaled.shape)
# Out:
# (5120, 57)
# (1707, 57)

# %%
#Undersampling
#from imblearn.under_sampling import RandomUnderSampler
#ros = RandomUnderSampler(random_state=1)
#X_resampled, y_resampled = ros.fit_resample(X_train_scaled, y_train)
#print(X_resampled.shape)
#print(y_resampled.shape)

# %%
print(len(X_train_scaled))
print(len(y_train))
# Out:
# 5120
# 5120

# %%
from sklearn.ensemble import RandomForestClassifier
# Create a random forest classifier.
rf_model = RandomForestClassifier(n_estimators=500, random_state=78)

# %%
# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
# Making predictions using the testing data.
predictions = rf_model.predict(X_test_scaled)

# %%
print(predictions)
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %%
len(predictions)
# Out:
# 1707

# %%
len(y_test)
# Out:
# 1707

# %%
#Model Evaluation
# Calculating the confusion matrix
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0         1522           25
# Actual 1           53          107
# Accuracy Score : 0.9543057996485061
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.98      0.98      1547
#          1.0       0.81      0.67      0.73       160
#
#     accuracy                           0.95      1707
#    macro avg       0.89      0.83      0.85      1707
# weighted avg       0.95      0.95      0.95      1707

# %%
# Calculate feature importance in the Random Forest model.
importances = rf_model.feature_importances_
importances
# Out:
# array([0.02715824, 0.0109514 , 0.01259884, 0.01179235, 0.00850803,
#        0.00914866, 0.0076964 , 0.00893247, 0.00959942, 0.01048609,
#        0.01777703, 0.01721661, 0.00923373, 0.02537199, 0.02160789,
#        0.00883659, 0.00782435, 0.00865927, 0.00843683, 0.00975457,
#        0.00851059, 0.00891871, 0.00838583, 0.05076243, 0.0410382 ,
#        0.00900286, 0.01567309, 0.03797269, 0.06987491, 0.0462226 ,
#        0.06166827, 0.02638307, 0.01648477, 0.09802082, 0.01231948,
#        0.04118744, 0.02240424, 0.00819961, 0.01334552, 0.01209762,
#        0.00898539, 0.0097704 , 0.01235333, 0.01933138, 0.00459816,
#        0.0093406 , 0.00983908, 0.00899229, 0.04982898, 0.00079245,
#        0.00086004, 0.00071019, 0.00036042, 0.00068195, 0.00089455,
#        0.00116489, 0.0014324 ])

# %%
# We can sort the features by their importance.
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.09802081654911901, 'gbpm'),
#  (0.06987491303814114, 'dporpag'),
#  (0.06166827008704075, 'bpm'),
#  (0.050762433252176956, 'porpag'),
#  (0.04982897773045996, 'Last_Yr_in_College_School_Yr_Num'),
#  (0.04622259782487144, 'stops'),
#  (0.04118744389125301, 'ogbpm'),
#  (0.04103820346433896, 'adjoe'),
#  (0.037972688898912144, 'adrtg'),
#  (0.027158242034545248, 'GP'),
#  (0.026383069654584063, 'obpm'),
#  (0.025371992028229602, 'twoPM'),
#  (0.022404244240644664, 'dgbpm'),
#  (0.021607889247959193, 'twoPA'),
#  (0.019331380127534156, 'pts'),
#  (0.01777702860478395, 'FTM'),
#  (0.017216608157116318, 'FTA'),
#  (0.016484773224306443, 'dbpm'),
#  (0.01567308557732928, 'drtg'),
#  (0.013345515411793586, 'dreb'),
#  (0.01259883768480225, 'Ortg'),
#  (0.01235332682468658, 'blk'),
#  (0.012319476038166133, 'mp'),
#  (0.01209762075566624, 'treb'),
#  (0.011792346993200734, 'usg'),
#  (0.010951401428040661, 'Min_per'),
#  (0.010486090577869025, 'TO_per'),
# ...

# %%
#BREAK

# %%
#BREAK

# %%
#BREAK

# %%
#Try Certain year of players
Years = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]
Output_df = pd.DataFrame()

for y in Years:
    Df_Year = Grouped_Player_Avgs_Clean[Grouped_Player_Avgs_Clean['Last_Yr_in_College_Date_Yr'] == y]
    Variables_Df_Year = Df_Year

    Variables_Df_Year = Variables_Df_Year.drop(columns=['pid','player_name','pick','Drafted','Round_Drafted'])

    #Encode School_Yr
    School_Yr_dict = {
        'Fr':1,
        'So':2,
        'Jr':3,
        'Sr':4
        }

    Variables_Df_Year["Last_Yr_in_College_School_Yr_Num"] = Variables_Df_Year["Last_Yr_in_College_School_Yr"].apply(lambda x: School_Yr_dict[x])
    

    Variables_Df_Year = Variables_Df_Year.drop(columns = ['Last_Yr_in_College_School_Yr'], axis=1)


    Variables_Df_Year_cat_encoded = pd.get_dummies(Variables_Df_Year, columns=['Last_Yr_in_College_Position'])


    if 'Last_Yr_in_College_Position_Unknown' in Variables_Df_Year_cat_encoded.columns:
        Variables_Df_Year_cat_encoded = Variables_Df_Year_cat_encoded.drop(columns=['Last_Yr_in_College_Position_Unknown'])   

    Target_Year = Df_Year['Drafted'].values

    X_Yr=Variables_Df_Year_cat_encoded
    y_Yr=Target_Year
    print(len(X_Yr))
    print(len(y_Yr))

    # Creating StandardScaler instance
    scaler = StandardScaler()

    # Fitting Standard Scaller
    X_scaler = scaler.fit(X_Yr)

    # Scaling data
    X_Yr_scaled = X_scaler.transform(X_Yr)

    print(X_Yr_scaled.shape)

    # Making predictions using the testing data.
    predictions_Yr = rf_model.predict(X_Yr_scaled)

    print(len(predictions_Yr))
    print(len(y_Yr))

    #Model Evaluation
    # Calculating the confusion matrix
    cm = confusion_matrix(y_Yr, predictions_Yr)
    cm_df = pd.DataFrame(
        cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
    )

    # Calculating the accuracy score
    acc_score = accuracy_score(y_Yr, predictions_Yr)

    # Displaying results
    print(y)
    print("Confusion Matrix")
    display(cm_df)
    print(f"Accuracy Score : {acc_score}")
    print("Classification Report")
    print(classification_report(y_Yr, predictions_Yr))

    #Create DF of Predictions vs Results
    Df_Year['Actual'] = y_Yr
    Df_Year['Predictions'] = predictions_Yr
    Output_df = Output_df.append(Df_Year)
# Out:
# 2010
# 874
# 874
# (874, 57)
# 874
# 874
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0          810           11
# Actual 1           12           41
# Accuracy Score : 0.9736842105263158
# Classification Report
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99       821
#          1.0       0.79      0.77      0.78        53
#
#     accuracy                           0.97       874
#    macro avg       0.89      0.88      0.88       874
# weighted avg       0.97      0.97      0.97       874
#
# 2011
# 900
# 900
# (900, 57)
# C:\Users\tyler\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:74: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
print(len(Output_df))
# Out:
# 13082

# %%
Output_df
# Out:
#          pid    GP  Min_per    Ortg    usg    eFG  TS_per  ORB_per  DRB_per  \
# 17        34  28.5    43.55  100.70  17.05  47.35  51.825     4.25    10.75
# 26        47  30.0    85.60  101.75  26.00  45.95  52.595     1.20     6.85
# 27        49  22.0    17.30   82.55  14.60  35.25  44.390     7.90     9.35
# 33        60  34.0    79.85  110.90  16.95  50.55  59.790     4.25     9.90
# 35        62  23.5    15.65   94.65  16.50  46.30  47.750     3.30    11.10
# ...      ...   ...      ...     ...    ...    ...     ...      ...      ...
# 22359  74187  19.0    57.80  109.50  17.50  59.10  61.380     5.90    16.20
# 22361  74190  18.0    47.50   67.40  20.70  37.20  38.000     0.90    11.80
# 22365  74203  16.0    12.90  129.50  13.20  67.90  65.840     8.50     8.50
# 22367  74217   9.0    17.10   86.90  21.80  39.10  40.090     7.30    12.30
# 22368  74218  13.0    11.00   99.10  15.10  60.00  55.370    10.20    21.20
#
# ...

# %%
Output_df.to_csv('Collective_Supervised_ML_Results.csv', index=False)
